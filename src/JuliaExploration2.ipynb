# %% [markdown]
# # Mulitple dispatch

# %% [markdown]
# How many multiplication methods do we have?

# %%
methods(*)
# Out:
# # 357 methods for generic function "*":
# [1] *(x::Bool, z::Complex{Bool}) in Base at complex.jl:290
# [2] *(x::Bool, y::Bool) in Base at bool.jl:98
# [3] *(x::Bool, y::T) where T<:AbstractFloat in Base at bool.jl:110
# [4] *(x::Bool, z::Complex) in Base at complex.jl:297
# [5] *(x::Bool, y::AbstractIrrational) in Base at irrationals.jl:139
# [6] *(a::Float16, b::Float16) in Base at float.jl:398
# [7] *(x::Float32, y::Float32) in Base at float.jl:404
# [8] *(x::Float64, y::Float64) in Base at float.jl:405
# [9] *(z::Complex{Bool}, x::Bool) in Base at complex.jl:291
# [10] *(z::Complex{Bool}, x::Real) in Base at complex.jl:309
# [11] *(r::Regex) in Base at regex.jl:660
# [12] *(::Missing, ::Missing) in Base at missing.jl:114
# [13] *(::Missing, ::Number) in Base at missing.jl:115
# [14] *(d::Missing, x::AbstractString) in Base at missing.jl:174
# [15] *(this::Base.Grisu.Float, other::Base.Grisu.Float) in Base.Grisu at grisu/float.jl:140
# [16] *(c::BigInt, x::BigFloat) in Base.MPFR at mpfr.jl:414
# [17] *(a::BigInt, b::BigInt, c::BigInt, d::BigInt, e::BigInt) in Base.GMP at gmp.jl:515
# [18] *(a::BigInt, b::BigInt, c::BigInt, d::BigInt) in Base.GMP at gmp.jl:514
# [19] *(a::BigInt, b::BigInt, c::BigInt) in Base.GMP at gmp.jl:513
# [20] *(x::BigInt, y::BigInt) in Base.GMP at gmp.jl:473
# [21] *(x::BigInt, c::Union{UInt16, UInt32, UInt64, UInt8}) in Base.GMP at gmp.jl:532
# [22] *(x::BigInt, c::Union{Int16, Int32, Int64, Int8}) in Base.GMP at gmp.jl:534
# [23] *(a::BigFloat, b::BigFloat, c::BigFloat, d::BigFloat, e::BigFloat) in Base.MPFR at mpfr.jl:564
# [24] *(a::BigFloat, b::BigFloat, c::BigFloat, d::BigFloat) in Base.MPFR at mpfr.jl:557
# [25] *(a::BigFloat, b::BigFloat, c::BigFloat) in Base.MPFR at mpfr.jl:551
# [26] *(x::BigFloat, c::BigInt) in Base.MPFR at mpfr.jl:410
# [27] *(x::BigFloat, y::BigFloat) in Base.MPFR at mpfr.jl:379
# [28] *(x::BigFloat, c::Union{UInt16, UInt32, UInt64, UInt8}) in Base.MPFR at mpfr.jl:386
# [29] *(x::BigFloat, c::Union{Int16, Int32, Int64, Int8}) in Base.MPFR at mpfr.jl:394
# [30] *(x::BigFloat, c::Union{Float16, Float32, Float64}) in Base.MPFR at mpfr.jl:402
# [31] *(B::BitArray{2}, J::LinearAlgebra.UniformScaling) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/uniformscaling.jl:195
# [32] *(y::AbstractFloat, x::Bool) in Base at bool.jl:112
# [33] *(x::T, y::T) where T<:Union{Int128, UInt128} in Base at int.jl:845
# [34] *(x::T, y::T) where T<:Union{Int128, Int16, Int32, Int64, Int8, UInt128, UInt16, UInt32, UInt64, UInt8} in Base at int.jl:54
# [35] *(c::Union{UInt16, UInt32, UInt64, UInt8}, x::BigInt) in Base.GMP at gmp.jl:533
# [36] *(c::Union{Int16, Int32, Int64, Int8}, x::BigInt) in Base.GMP at gmp.jl:535
# [37] *(a::Integer, b::Integer) in Base at int.jl:857
# [38] *(x::Real, r::StepRangeLen{#s69,#s68,S} where S where #s68<:Base.TwicePrecision where #s69<:Real) in Base at twiceprecision.jl:479
# [39] *(z::Complex, w::Complex) in Base at complex.jl:277
# [40] *(z::Complex, x::Bool) in Base at complex.jl:298
# [41] *(x::Real, z::Complex{Bool}) in Base at complex.jl:308
# [42] *(x::Real, z::Complex) in Base at complex.jl:320
# [43] *(z::Complex, x::Real) in Base at complex.jl:321
# [44] *(x::Rational, y::Rational) in Base at rational.jl:270
# [45] *(a::Integer, index::CartesianIndex{N}) where N in Base.IteratorsMD at multidimensional.jl:120
# [46] *(c::Union{UInt16, UInt32, UInt64, UInt8}, x::BigFloat) in Base.MPFR at mpfr.jl:390
# [47] *(c::Union{Int16, Int32, Int64, Int8}, x::BigFloat) in Base.MPFR at mpfr.jl:398
# [48] *(c::Union{Float16, Float32, Float64}, x::BigFloat) in Base.MPFR at mpfr.jl:406
# [49] *(x::AbstractIrrational, y::AbstractIrrational) in Base at irrationals.jl:137
# [50] *(y::Real, x::Dates.Period) in Dates at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/Dates/src/periods.jl:91
# [51] *(x::Real, A::LinearAlgebra.Hermitian) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:616
# [52] *(x::Number) in Base at operators.jl:505
# [53] *(x::T, y::T) where T<:Number in Base at promotion.jl:385
# [54] *(x::Number, y::Number) in Base at promotion.jl:312
# [55] *(x::Base.TwicePrecision{#s69} where #s69<:Union{Float16, Float32, Float64}, v::Integer) in Base at twiceprecision.jl:286
# [56] *(x::Base.TwicePrecision, v::Number) in Base at twiceprecision.jl:282
# [57] *(v::Number, x::Base.TwicePrecision) in Base at twiceprecision.jl:291
# [58] *(x::Base.TwicePrecision{T}, y::Base.TwicePrecision{T}) where T in Base at twiceprecision.jl:294
# [59] *(x::Base.TwicePrecision, y::Base.TwicePrecision) in Base at twiceprecision.jl:298
# [60] *(r::StepRangeLen{#s69,#s68,S} where S where #s68<:Base.TwicePrecision where #s69<:Real, x::Real) in Base at twiceprecision.jl:481
# [61] *(X::Union{DenseArray{P,N}, Base.ReinterpretArray{P,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{P,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{P,N,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where N, y::Real) where P<:Dates.Period in Dates at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/Dates/src/deprecated.jl:46
# [62] *(u::LinearAlgebra.Adjoint{T,#s664} where #s664<:(AbstractArray{T,1} where T) where T, v::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(LinearAlgebra.Transpose{T,#s664} where #s664<:(AbstractArray{T,1} where T) where T) where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/adjtrans.jl:263
# [63] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664, B::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:LinearAlgebra.AbstractTriangular where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:2133
# [64] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s664, B::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:LinearAlgebra.AbstractTriangular where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:1049
# [65] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:SparseArrays.AbstractSparseMatrixCSC where #s664, B::Union{DenseArray{T,2}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, LinearAlgebra.Adjoint{#s664,#s663} where #s663<:Union{DenseArray{T,2}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, LinearAlgebra.LowerTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgebra.UnitLowerTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgebra.UnitUpperTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgebra.UpperTriangular{T,S} where S<:AbstractArray{T,2}} where #s664, LinearAlgebra.LowerTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgeb ...
# [66] *(v::LinearAlgebra.Adjoint{T,#s664} where #s664<:(AbstractArray{T,1} where T) where T, A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:2120
# [67] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664, B::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:1045
# [68] *(X::Union{DenseArray{T,2}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, LinearAlgebra.Adjoint{#s664,#s663} where #s663<:Union{DenseArray{T,2}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, LinearAlgebra.LowerTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgebra.UnitLowerTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgebra.UnitUpperTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgebra.UpperTriangular{T,S} where S<:AbstractArray{T,2}} where #s664, LinearAlgebra.LowerTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgebra.Transpose{#s662,#s661} where #s661<:Union{DenseArray{T,2}, Base.ReinterpretArray{T,2,S,A} where S whe ...
# [69] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664, B::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(AbstractArray{T,1} where T) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:2642
# [70] *(adjQ::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractQ where #s664, adjB::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(Union{DenseArray{T,1}, DenseArray{T,2}, Base.ReinterpretArray{T,1,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,1,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,1,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where T) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/qr.jl:641
# [71] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{DenseArray{T,1}, DenseArray{T,2}, Base.ReinterpretArray{T,1,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,1,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,1,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where T) where #s664, adjQ::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:LinearAlgebra.AbstractQ where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/qr.jl:744
# [72] *(u::LinearAlgebra.Adjoint{T,#s664} where #s664<:(AbstractArray{T,1} where T) where T, A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractQ where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/qr.jl:732
# [73] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.LQPackedQ where #s664, adjB::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(Union{DenseArray{T,1}, DenseArray{T,2}, Base.ReinterpretArray{T,1,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,1,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,1,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where T) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/lq.jl:219
# [74] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{DenseArray{T,2}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where T) where #s664, adjQ::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:LinearAlgebra.LQPackedQ where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/lq.jl:256
# [75] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s664, adjB::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:599
# [76] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s664, adjB::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:601
# [77] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s664, adjB::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:603
# [78] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s664, adjB::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:600
# [79] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}, LinearAlgebra.Symmetric{Complex{T},S}} where S where T<:Real) where #s664, adjB::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:602
# [80] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s664, adjB::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}, LinearAlgebra.Symmetric{Complex{T},S}} where S where T<:Real) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:604
# [81] *(adjD::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.Diagonal where #s664, adjA::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/diagonal.jl:373
# [82] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(AbstractArray{T,1} where T) where #s664, B::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:1026
# [83] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s664, adjD::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:LinearAlgebra.Diagonal where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/diagonal.jl:372
# [84] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s664, B::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(AbstractArray{T,1} where T) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:1035
# [85] *(D::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.Diagonal where #s664, B::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:LinearAlgebra.Diagonal where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/diagonal.jl:259
# [86] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:SparseArrays.AbstractSparseMatrixCSC where #s664, B::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:SparseArrays.AbstractSparseMatrixCSC where #s662) in SparseArrays at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SparseArrays/src/linalg.jl:168
# [87] *(u::LinearAlgebra.Adjoint{T,#s664} where #s664<:(AbstractArray{T,1} where T) where T, v::LinearAlgebra.Adjoint{T,#s664} where #s664<:(AbstractArray{T,1} where T) where T) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/adjtrans.jl:256
# [88] *(u::LinearAlgebra.Adjoint{T,#s664} where #s664<:(AbstractArray{T,1} where T) where T, v::LinearAlgebra.Transpose{#s664,#s663} where #s663<:(LinearAlgebra.Adjoint{T,#s664} where #s664<:(AbstractArray{T,1} where T) where T) where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/adjtrans.jl:267
# [89] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:Union{DenseArray{T,2}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where #s664, x::Union{DenseArray{S,1}, Base.ReinterpretArray{S,1,S1,A} where S1 where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{S,1,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{S,1,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}}) where {T<:Union{Complex{Float32}, Complex{Float64}, Float32, Float64}, S} in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/matmul.jl:106
# [90] *(xformA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.UpperTriangular where #s664, B::LinearAlgebra.LowerTriangular) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:1813
# [91] *(xformA::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:LinearAlgebra.UnitUpperTriangular where #s662, B::LinearAlgebra.LowerTriangular) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:1822
# [92] *(xformA::LinearAlgebra.Adjoint{#s660,#s659} where #s659<:LinearAlgebra.LowerTriangular where #s660, B::LinearAlgebra.UpperTriangular) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:1831
# [93] *(xformA::LinearAlgebra.Adjoint{#s658,#s657} where #s657<:LinearAlgebra.UnitLowerTriangular where #s658, B::LinearAlgebra.UpperTriangular) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:1840
# [94] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664, B::LinearAlgebra.AbstractTriangular) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:1931
# [95] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664, B::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(AbstractArray{T,2} where T) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:2134
# [96] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664, B::LinearAlgebra.Transpose{#s662,#s661} where #s661<:LinearAlgebra.AbstractTriangular where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:2639
# [97] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664, B::LinearAlgebra.Transpose{#s662,#s661} where #s661<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}, LinearAlgebra.Symmetric{Complex{T},S}} where S where T<:Real) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:1046
# [98] *(X::Union{DenseArray{T,2}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, LinearAlgebra.Adjoint{#s664,#s663} where #s663<:Union{DenseArray{T,2}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, LinearAlgebra.LowerTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgebra.UnitLowerTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgebra.UnitUpperTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgebra.UpperTriangular{T,S} where S<:AbstractArray{T,2}} where #s664, LinearAlgebra.LowerTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgebra.Transpose{#s662,#s661} where #s661<:Union{DenseArray{T,2}, Base.ReinterpretArray{T,2,S,A} where S whe ...
# [99] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664, B::LinearAlgebra.Transpose{#s662,#s661} where #s661<:(AbstractArray{T,2} where T) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:2643
# [100] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664, B::LinearAlgebra.Transpose{#s662,#s661} where #s661<:(AbstractArray{T,1} where T) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:2644
# [101] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664, D::LinearAlgebra.Diagonal) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/diagonal.jl:219
# ...
# [302] *(A::SuiteSparse.CHOLMOD.Sparse, B::SuiteSparse.CHOLMOD.Sparse) in SuiteSparse.CHOLMOD at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SuiteSparse/src/cholmod.jl:1233
# [303] *(A::SuiteSparse.CHOLMOD.Sparse, B::SuiteSparse.CHOLMOD.Dense) in SuiteSparse.CHOLMOD at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SuiteSparse/src/cholmod.jl:1234
# [304] *(A::SuiteSparse.CHOLMOD.Sparse, B::Union{Array{T,1}, Array{T,2}} where T) in SuiteSparse.CHOLMOD at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SuiteSparse/src/cholmod.jl:1235
# [305] *(A::SuiteSparse.CHOLMOD.Sparse{Tv}, adjB::LinearAlgebra.Adjoint{Tv,SuiteSparse.CHOLMOD.Sparse{Tv}}) where Tv<:Float64 in SuiteSparse.CHOLMOD at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SuiteSparse/src/cholmod.jl:1238
# [306] *(A::LinearAlgebra.Symmetric{Float64,SparseArrays.SparseMatrixCSC{Float64,Ti}}, B::Union{SparseArrays.SparseMatrixCSC{Float64,Ti}, SparseArrays.SparseVector{Float64,Ti}}) where Ti in SuiteSparse.CHOLMOD at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SuiteSparse/src/cholmod.jl:1858
# [307] *(A::LinearAlgebra.Hermitian{Complex{Float64},SparseArrays.SparseMatrixCSC{Complex{Float64},Ti}}, B::Union{SparseArrays.SparseMatrixCSC{Complex{Float64},Ti}, SparseArrays.SparseVector{Complex{Float64},Ti}}) where Ti in SuiteSparse.CHOLMOD at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SuiteSparse/src/cholmod.jl:1860
# [308] *(A::LinearAlgebra.Hermitian{Float64,SparseArrays.SparseMatrixCSC{Float64,Ti}}, B::Union{SparseArrays.SparseMatrixCSC{Float64,Ti}, SparseArrays.SparseVector{Float64,Ti}}) where Ti in SuiteSparse.CHOLMOD at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SuiteSparse/src/cholmod.jl:1862
# [309] *(A::Union{SparseArrays.SparseMatrixCSC{Float64,Ti}, SparseArrays.SparseVector{Float64,Ti}}, B::LinearAlgebra.Symmetric{Float64,SparseArrays.SparseMatrixCSC{Float64,Ti}}) where Ti in SuiteSparse.CHOLMOD at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SuiteSparse/src/cholmod.jl:1865
# [310] *(A::Union{SparseArrays.SparseMatrixCSC{Complex{Float64},Ti}, SparseArrays.SparseVector{Complex{Float64},Ti}}, B::LinearAlgebra.Hermitian{Complex{Float64},SparseArrays.SparseMatrixCSC{Complex{Float64},Ti}}) where Ti in SuiteSparse.CHOLMOD at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SuiteSparse/src/cholmod.jl:1867
# [311] *(A::Union{SparseArrays.SparseMatrixCSC{Float64,Ti}, SparseArrays.SparseVector{Float64,Ti}}, B::LinearAlgebra.Hermitian{Float64,SparseArrays.SparseMatrixCSC{Float64,Ti}}) where Ti in SuiteSparse.CHOLMOD at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SuiteSparse/src/cholmod.jl:1869
# [312] *(x::AbstractArray{#s69,2} where #s69<:Number) in Base at abstractarraymath.jl:98
# [313] *(B::Number, A::LinearAlgebra.SymTridiagonal) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/tridiag.jl:161
# [314] *(B::Number, A::LinearAlgebra.Tridiagonal) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/tridiag.jl:660
# [315] *(x::Number, A::LinearAlgebra.UpperTriangular) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:847
# [316] *(x::Number, A::LinearAlgebra.UnitUpperTriangular) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:850
# [317] *(x::Number, A::LinearAlgebra.LowerTriangular) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:847
# [318] *(x::Number, A::LinearAlgebra.UnitLowerTriangular) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:850
# [319] *(x::Number, A::LinearAlgebra.Symmetric) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:614
# [320] *(x::Number, D::LinearAlgebra.Diagonal) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/diagonal.jl:159
# [321] *(B::Number, A::LinearAlgebra.Bidiagonal) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/bidiag.jl:328
# [322] *(a::Number, x::Union{SubArray{T,1,#s664,Tuple{Base.Slice{Base.OneTo{Int64}},Int64},false} where #s664<:SparseArrays.AbstractSparseMatrixCSC, SparseArrays.SparseVector{T,Ti} where Ti<:Integer} where T) in SparseArrays at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SparseArrays/src/sparsevector.jl:1407
# [323] *(A::Number, B::AbstractArray) in Base at arraymath.jl:52
# [324] *(A::AbstractArray, B::Number) in Base at arraymath.jl:55
# [325] *(s1::Union{AbstractChar, AbstractString}, ss::Union{AbstractChar, AbstractString}...) in Base at strings/basic.jl:231
# [326] *(r1::Union{Regex, AbstractChar, AbstractString}, rs::Union{Regex, AbstractChar, AbstractString}...) in Base at regex.jl:640
# [327] *(index::CartesianIndex, a::Integer) in Base.IteratorsMD at multidimensional.jl:121
# [328] *(::Number, ::Missing) in Base at missing.jl:116
# [329] *(d::AbstractString, x::Missing) in Base at missing.jl:175
# [330] *(x::P, y::Real) where P<:Dates.Period in Dates at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/Dates/src/periods.jl:90
# [331] *(u::AbstractArray{T,1} where T, v::Union{LinearAlgebra.Adjoint{T,#s664}, LinearAlgebra.Transpose{T,#s664}} where #s664<:(AbstractArray{T,1} where T) where T) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/adjtrans.jl:253
# [332] *(A::AbstractArray{T,2} where T, B::LinearAlgebra.AbstractTriangular) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:2095
# [333] *(A::AbstractArray{T,2} where T, adjB::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:2102
# [334] *(A::AbstractArray{T,2} where T, transB::LinearAlgebra.Transpose{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:2110
# [335] *(A::AbstractArray{T,2} where T, transB::LinearAlgebra.Transpose{#s664,#s663} where #s663<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}, LinearAlgebra.Symmetric{Complex{T},S}} where S where T<:Real) where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:586
# [336] *(A::AbstractArray{T,2} where T, adjB::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:590
# [337] *(A::AbstractArray{T,2} where T, D::LinearAlgebra.Diagonal) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/diagonal.jl:170
# [338] *(A::AbstractArray{T,2} where T, adjR::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractRotation where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/givens.jl:14
# [339] *(A::AbstractArray{T,2}, x::AbstractArray{S,1}) where {T, S} in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/matmul.jl:50
# [340] *(a::AbstractArray{T,1} where T, transB::LinearAlgebra.Transpose{#s664,#s663} where #s663<:(AbstractArray{T,2} where T) where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/matmul.jl:56
# [341] *(a::AbstractArray{T,1} where T, adjB::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(AbstractArray{T,2} where T) where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/matmul.jl:60
# [342] *(A::AbstractArray{T,1} where T, adjR::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractRotation where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/givens.jl:13
# [343] *(a::AbstractArray{T,1} where T, B::AbstractArray{T,2} where T) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/matmul.jl:63
# [344] *(A::AbstractArray{T,2} where T, B::AbstractArray{T,2} where T) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/matmul.jl:152
# [345] *(A::LinearAlgebra.LQ{TA,S} where S<:AbstractArray{TA,2}, B::Union{DenseArray{TB,1}, DenseArray{TB,2}, Base.ReinterpretArray{TB,1,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReinterpretArray{TB,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{TB,1,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{TB,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{TB,1,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, SubArray{TB,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}}) where {TA, TB} in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/lq.jl:180
# [346] *(J1::LinearAlgebra.UniformScaling, J2::LinearAlgebra.UniformScaling) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/uniformscaling.jl:194
# [347] *(J::LinearAlgebra.UniformScaling, B::BitArray{2}) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/uniformscaling.jl:196
# [348] *(A::AbstractArray{T,2} where T, J::LinearAlgebra.UniformScaling) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/uniformscaling.jl:197
# [349] *(J::LinearAlgebra.UniformScaling, A::Union{AbstractArray{T,1}, AbstractArray{T,2}} where T) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/uniformscaling.jl:198
# [350] *(x::Number, J::LinearAlgebra.UniformScaling) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/uniformscaling.jl:199
# [351] *(J::LinearAlgebra.UniformScaling, x::Number) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/uniformscaling.jl:200
# [352] *(F::LinearAlgebra.Hessenberg{#s664,#s663,S,W,V} where V<:Number where W<:(AbstractArray{T,1} where T) where S<:(AbstractArray{T,2} where T) where #s663<:AbstractArray{T,2} where #s664, x::S) where {T, S<:Number} in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/hessenberg.jl:541
# [353] *(x::S, F::LinearAlgebra.Hessenberg{#s664,#s663,S,W,V} where V<:Number where W<:(AbstractArray{T,1} where T) where S<:(AbstractArray{T,2} where T) where #s663<:AbstractArray{T,2} where #s664) where {T, S<:Number} in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/hessenberg.jl:549
# [354] *(R::LinearAlgebra.AbstractRotation{T}, A::Union{AbstractArray{S,1}, AbstractArray{S,2}}) where {T, S} in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/givens.jl:10
# [355] *(A::AbstractArray{T,2}, R::LinearAlgebra.AbstractRotation{S}) where {T, S} in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/givens.jl:21
# [356] *(G1::LinearAlgebra.Givens{T}, G2::LinearAlgebra.Givens{T}) where T in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/givens.jl:383
# [357] *(a, b, c, xs...) in Base at operators.jl:529

# %%
@which 12*1
# Out:
# *(x::T, y::T) where T<:Union{Int128, Int16, Int32, Int64, Int8, UInt128, UInt16, UInt32, UInt64, UInt8} in Base at int.jl:54

# %%
@code_lowered 12*2
# Out:
# CodeInfo(
# 1 ─ %1 = Base.mul_int(x, y)
# └──      return %1
# )

# %%
@code_lowered 2.0*2.9
# Out:
# CodeInfo(
# 1 ─ %1 = Base.mul_float(x, y)
# └──      return %1
# )

# %% [markdown]
# Different low level code for different types

# %%
"This is "*"cool"
# Out:
# "This is cool"

# %% [markdown]
# ## Generic code

# %%
my_func(x,y)=x+y
# Out:
# my_func (generic function with 1 method)

# %%
my_func(1,3)
# Out:
# 4

# %%
my_func(1.0,3.0)
# Out:
# 4.0

# %%
my_func(complex(1,2),3.0)
# Out:
# 4.0 + 2.0im

# %%
function my_func(x::Int, y::Int)
    x*y
end
# Out:
# my_func (generic function with 2 methods)

# %%
my_func(1,3)
# Out:
# 3

# %%
my_func(1.0,3)
# Out:
# 4.0

# %%
@which my_func(1.0,3)
# Out:
# my_func(x, y) in Main at In[6]:1

# %%
@which my_func(1,3)
# Out:
# my_func(x::Int64, y::Int64) in Main at In[10]:2

# %% [markdown]
# Julia will trying to specialize on the most type specific method, before it goes to the generic fallback.

# %% [markdown]
# # Julia Types

# %%
struct Color{T} <: Number where {T<:Integer}
    R::T
    G::T
    B::T
end

# %%
my_color=Color(4,5,10)
# Out:
# Color{Int64}(4, 5, 10)

# %% [markdown]
# Accessing the fields of Color

# %%
my_color.R
# Out:
# 4

# %%
my_color.G
# Out:
# 5

# %%
my_color
# Out:
# Color{Int64}(4, 5, 10)

# %% [markdown]
# If I want to print the `Color` objects differntly. One way to do that is by modifying its show function.

# %% [markdown]
# If we try to change it directly in the current `Main` scope by running
# ```julia
# show(io::IO,c::Color)=print(io,"Red is $(c.R), Green is $(c.G), Blue is $(c.B)")
# ```
#
# It will have no effect. To investiage further, we can run
#
#
# ```julia
# methods(show)
# ```)
#
# <div>
# <img align="left" src="attachment:image.png" width="200" height="200"/>
# </div>

# %% [markdown]
# What is happening here is that our there is `display` method in the `Base` Module that then calls show. This display methods is in its own **namespace** and hence it is *blind* to our `show` definition.
#
# ![image.png](attachment:image.png)
#
# Now we have created a conflicit that can not be resolved. We would have to restart the kernel to fix this.
#
#
#
# So instead we do it the right way.

# %%
import Base.show
show(io::IO,c::Color)=print(io,"R$(c.R)G$(c.G)B$(c.B)")
# Out:
# show (generic function with 234 methods)

# %%
my_color
# Out:
# R4G5B10

# %%
import Base:*

# %%
function *(c1::Color,c2::Color)
    Color(c1.R*c2.R%256, c1.G*c2.G%256, c1.B*c2.B%256)
end
# Out:
# * (generic function with 358 methods)

# %%
function *(n::Number,c::Color)
    Color(c.R*n%256, c.G*n%256, c.B*n%256)
end
# Out:
# * (generic function with 359 methods)

# %%
Base.:*(c::Color,n::Number) =Base.:*(n,c)

# %%
Color(1,2,500)*Color(4,5,3)
# Out:
# R4G10B220

# %%
Color(1,2,3)*2
# Out:
# R2G4B6

# %%
2*Color(1,2,3)
# Out:
# R2G4B6

# %% [markdown]
# We can create an array of colors.

# %%
A=[Color(rand(0:255,3)...) for i=1:5, j=1:5]
# Out:
# 5×5 Array{Color{Int64},2}:
#  R67G242B236   R250G103B83      R91G4B54  R121G250B107    R148G25B31
#  R189G167B73   R109G47B153     R21G73B97   R144G44B177   R44G244B135
#  R142G68B124  R204G153B161  R133G157B182    R62G89B198  R221G114B173
#   R65G73B172    R152G11B87    R115G106B3     R88G27B21   R211G253B27
#  R25G251B126     R233G99B3   R252G76B110    R233G4B228   R234G72B189

# %%
B=[Color(rand(0:255,3)...) for i=1:5, j=1:5]
# Out:
# 5×5 Array{Color{Int64},2}:
#   R189G217B82  R17G174B243     R72G83B23   R33G96B178    R40G107B25
#    R73G58B203   R221G6B183  R154G198B239  R238G61B150   R154G52B217
#   R174G10B104   R97G45B244    R78G85B245  R137G52B117  R198G139B133
#  R145G120B175   R3G134B247    R122G74B48  R36G155B157  R185G208B129
#    R122G94B55   R181G34B81  R192G176B183  R116G131B77   R86G253B212

# %%
A*B
# Out:
# + not defined for Color{Int64}
#
# Stacktrace:
#  [1] error(::String, ::String, ::Type{T} where T) at ./error.jl:42
#  [2] no_op_err(::String, ::Type{T} where T) at ./promotion.jl:383
#  [3] +(::Color{Int64}, ::Color{Int64}) at ./promotion.jl:384
#  [4] _generic_matmatmul!(::Array{Union{},2}, ::Char, ::Char, ::Array{Color{Int64},2}, ::Array{Color{Int64},2}, ::LinearAlgebra.MulAddMul{true,true,Bool,Bool}) at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.4/LinearAlgebra/src/matmul.jl:814
#  [5] generic_matmatmul!(::Array{Union{},2}, ::Char, ::Char, ::Array{Color{Int64},2}, ::Array{Color{Int64},2}, ::LinearAlgebra.MulAddMul{true,true,Bool,Bool}) at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.4/LinearAlgebra/src/matmul.jl:724
#  [6] mul! at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.4/LinearAlgebra/src/matmul.jl:235 [inlined]
#  [7] mul! at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.4/LinearAlgebra/src/matmul.jl:208 [inlined]
#  [8] *(::Array{Color{Int64},2}, ::Array{Color{Int64},2}) at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.4/LinearAlgebra/src/matmul.jl:153
#  [9] top-level scope at In[31]:1

# %% [markdown]
# Oh we can not multiply matrices without defining the `+` operator

# %%
import Base:+

# %%
function +(c1::Color,c2::Color)
    Color((c1.R+c2.R)%256, (c1.G+c2.G)%256, (c1.B+c2.B)%256)
end
# Out:
# + (generic function with 167 methods)

# %%
function +(n::Integer,c::Color)
    Color((c.R+n)%256, (c.G+n)%256, (c.B+n)%256)
end
+(c::Color,n::Integer)=+(n::Integer,c::Color)
# Out:
# + (generic function with 169 methods)

# %%
import Base: convert, promote_rule #<== allows extending them

convert(::Type{Color{T}}, x::Real) where {T<:Real}= (x = convert(T,x); Color(x,x,x))

promote_rule(::Type{Color{A}}, ::Type{B}) where {A<:Real,B<:Real}= 
    Color{promote_type(A,B)}
# Out:
# promote_rule (generic function with 123 methods)

# %% [markdown]
# Now we try again

# %%
A*B
# Out:
# 5×5 Array{Color{Int64},2}:
#   R172G254B39  R207G200B221  R160G232B152   R214G68B90    R103G19B12
#    R108G71B29  R103G225B156   R192G52B236   R32G39B229    R48G224B52
#    R216G4B216    R234G33B10  R122G157B108   R255G18B51   R210G185B45
#   R229G17B117     R83G62B31   R242G29B201   R56G87B241      R4G70B11
#  R171G121B228   R119G240B96   R132G215B64  R127G107B81  R247G177B103

# %% [markdown]
# The cool thing is the didn't have to define the how multiplication works for this newly invented type... you only need to define the promotion rules.
#
#
# More examples of of multiple dispatch and great discusion can be found [here](https://github.com/mbeltagy/JuliaTeachingExploration/blob/master/src/multiple_dispatch.ipynb).

# %% [markdown]
# ### Context Matters!

# %%
using Random

# %%
?Random.SamplerTrivial
# Out:
#   SamplerTrivial(x)
#
#   Create a sampler that just wraps the given value x. This is the default
#   fall-back for values. The eltype of this sampler is equal to eltype(x).
#
#   The recommended use case is sampling from values without precomputed data.

# %%
SamplerTrivial
# Out:
# UndefVarError: SamplerTrivial not defined
#
# Stacktrace:
#  [1] top-level scope at In[39]:1

# %%
methods(my_func)
# Out:
# # 2 methods for generic function "my_func":
# [1] my_func(x::Int64, y::Int64) in Main at In[10]:2
# [2] my_func(x, y) in Main at In[6]:1

# %%
methods(*)
# Out:
# # 360 methods for generic function "*":
# [1] *(x::Bool, z::Complex{Bool}) in Base at complex.jl:290
# [2] *(x::Bool, y::Bool) in Base at bool.jl:98
# [3] *(x::Bool, y::T) where T<:AbstractFloat in Base at bool.jl:110
# [4] *(x::Bool, z::Complex) in Base at complex.jl:297
# [5] *(x::Bool, y::AbstractIrrational) in Base at irrationals.jl:139
# [6] *(a::Float16, b::Float16) in Base at float.jl:398
# [7] *(x::Float32, y::Float32) in Base at float.jl:404
# [8] *(x::Float64, y::Float64) in Base at float.jl:405
# [9] *(z::Complex{Bool}, x::Bool) in Base at complex.jl:291
# [10] *(z::Complex{Bool}, x::Real) in Base at complex.jl:309
# [11] *(r::Regex) in Base at regex.jl:660
# [12] *(::Missing, ::Missing) in Base at missing.jl:114
# [13] *(::Missing, ::Number) in Base at missing.jl:115
# [14] *(d::Missing, x::AbstractString) in Base at missing.jl:174
# [15] *(this::Base.Grisu.Float, other::Base.Grisu.Float) in Base.Grisu at grisu/float.jl:140
# [16] *(c::BigInt, x::BigFloat) in Base.MPFR at mpfr.jl:414
# [17] *(a::BigInt, b::BigInt, c::BigInt, d::BigInt, e::BigInt) in Base.GMP at gmp.jl:515
# [18] *(a::BigInt, b::BigInt, c::BigInt, d::BigInt) in Base.GMP at gmp.jl:514
# [19] *(a::BigInt, b::BigInt, c::BigInt) in Base.GMP at gmp.jl:513
# [20] *(x::BigInt, y::BigInt) in Base.GMP at gmp.jl:473
# [21] *(x::BigInt, c::Union{UInt16, UInt32, UInt64, UInt8}) in Base.GMP at gmp.jl:532
# [22] *(x::BigInt, c::Union{Int16, Int32, Int64, Int8}) in Base.GMP at gmp.jl:534
# [23] *(a::BigFloat, b::BigFloat, c::BigFloat, d::BigFloat, e::BigFloat) in Base.MPFR at mpfr.jl:564
# [24] *(a::BigFloat, b::BigFloat, c::BigFloat, d::BigFloat) in Base.MPFR at mpfr.jl:557
# [25] *(a::BigFloat, b::BigFloat, c::BigFloat) in Base.MPFR at mpfr.jl:551
# [26] *(x::BigFloat, c::BigInt) in Base.MPFR at mpfr.jl:410
# [27] *(x::BigFloat, y::BigFloat) in Base.MPFR at mpfr.jl:379
# [28] *(x::BigFloat, c::Union{UInt16, UInt32, UInt64, UInt8}) in Base.MPFR at mpfr.jl:386
# [29] *(x::BigFloat, c::Union{Int16, Int32, Int64, Int8}) in Base.MPFR at mpfr.jl:394
# [30] *(x::BigFloat, c::Union{Float16, Float32, Float64}) in Base.MPFR at mpfr.jl:402
# [31] *(B::BitArray{2}, J::LinearAlgebra.UniformScaling) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/uniformscaling.jl:195
# [32] *(y::AbstractFloat, x::Bool) in Base at bool.jl:112
# [33] *(x::T, y::T) where T<:Union{Int128, UInt128} in Base at int.jl:845
# [34] *(x::T, y::T) where T<:Union{Int128, Int16, Int32, Int64, Int8, UInt128, UInt16, UInt32, UInt64, UInt8} in Base at int.jl:54
# [35] *(c::Union{UInt16, UInt32, UInt64, UInt8}, x::BigInt) in Base.GMP at gmp.jl:533
# [36] *(c::Union{Int16, Int32, Int64, Int8}, x::BigInt) in Base.GMP at gmp.jl:535
# [37] *(a::Integer, b::Integer) in Base at int.jl:857
# [38] *(x::Real, r::StepRangeLen{#s69,#s68,S} where S where #s68<:Base.TwicePrecision where #s69<:Real) in Base at twiceprecision.jl:479
# [39] *(z::Complex, w::Complex) in Base at complex.jl:277
# [40] *(z::Complex, x::Bool) in Base at complex.jl:298
# [41] *(x::Real, z::Complex{Bool}) in Base at complex.jl:308
# [42] *(x::Real, z::Complex) in Base at complex.jl:320
# [43] *(z::Complex, x::Real) in Base at complex.jl:321
# [44] *(x::Rational, y::Rational) in Base at rational.jl:270
# [45] *(a::Integer, index::CartesianIndex{N}) where N in Base.IteratorsMD at multidimensional.jl:120
# [46] *(c::Union{UInt16, UInt32, UInt64, UInt8}, x::BigFloat) in Base.MPFR at mpfr.jl:390
# [47] *(c::Union{Int16, Int32, Int64, Int8}, x::BigFloat) in Base.MPFR at mpfr.jl:398
# [48] *(c::Union{Float16, Float32, Float64}, x::BigFloat) in Base.MPFR at mpfr.jl:406
# [49] *(x::AbstractIrrational, y::AbstractIrrational) in Base at irrationals.jl:137
# [50] *(y::Real, x::Dates.Period) in Dates at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/Dates/src/periods.jl:91
# [51] *(x::Real, A::LinearAlgebra.Hermitian) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:616
# [52] *(c1::Color, c2::Color) in Main at In[23]:2
# [53] *(c::Color, n::Number) in Main at In[25]:1
# [54] *(x::Number) in Base at operators.jl:505
# [55] *(n::Number, c::Color) in Main at In[24]:2
# [56] *(x::T, y::T) where T<:Number in Base at promotion.jl:385
# [57] *(x::Number, y::Number) in Base at promotion.jl:312
# [58] *(x::Base.TwicePrecision{#s69} where #s69<:Union{Float16, Float32, Float64}, v::Integer) in Base at twiceprecision.jl:286
# [59] *(x::Base.TwicePrecision, v::Number) in Base at twiceprecision.jl:282
# [60] *(v::Number, x::Base.TwicePrecision) in Base at twiceprecision.jl:291
# [61] *(x::Base.TwicePrecision{T}, y::Base.TwicePrecision{T}) where T in Base at twiceprecision.jl:294
# [62] *(x::Base.TwicePrecision, y::Base.TwicePrecision) in Base at twiceprecision.jl:298
# [63] *(r::StepRangeLen{#s69,#s68,S} where S where #s68<:Base.TwicePrecision where #s69<:Real, x::Real) in Base at twiceprecision.jl:481
# [64] *(X::Union{DenseArray{P,N}, Base.ReinterpretArray{P,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{P,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{P,N,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where N, y::Real) where P<:Dates.Period in Dates at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/Dates/src/deprecated.jl:46
# [65] *(u::LinearAlgebra.Adjoint{T,#s664} where #s664<:(AbstractArray{T,1} where T) where T, v::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(LinearAlgebra.Transpose{T,#s664} where #s664<:(AbstractArray{T,1} where T) where T) where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/adjtrans.jl:263
# [66] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664, B::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:LinearAlgebra.AbstractTriangular where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:2133
# [67] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s664, B::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:LinearAlgebra.AbstractTriangular where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:1049
# [68] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:SparseArrays.AbstractSparseMatrixCSC where #s664, B::Union{DenseArray{T,2}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, LinearAlgebra.Adjoint{#s664,#s663} where #s663<:Union{DenseArray{T,2}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, LinearAlgebra.LowerTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgebra.UnitLowerTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgebra.UnitUpperTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgebra.UpperTriangular{T,S} where S<:AbstractArray{T,2}} where #s664, LinearAlgebra.LowerTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgeb ...
# [69] *(v::LinearAlgebra.Adjoint{T,#s664} where #s664<:(AbstractArray{T,1} where T) where T, A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:2120
# [70] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664, B::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:1045
# [71] *(X::Union{DenseArray{T,2}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, LinearAlgebra.Adjoint{#s664,#s663} where #s663<:Union{DenseArray{T,2}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, LinearAlgebra.LowerTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgebra.UnitLowerTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgebra.UnitUpperTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgebra.UpperTriangular{T,S} where S<:AbstractArray{T,2}} where #s664, LinearAlgebra.LowerTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgebra.Transpose{#s662,#s661} where #s661<:Union{DenseArray{T,2}, Base.ReinterpretArray{T,2,S,A} where S whe ...
# [72] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664, B::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(AbstractArray{T,1} where T) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:2642
# [73] *(adjQ::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractQ where #s664, adjB::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(Union{DenseArray{T,1}, DenseArray{T,2}, Base.ReinterpretArray{T,1,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,1,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,1,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where T) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/qr.jl:641
# [74] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{DenseArray{T,1}, DenseArray{T,2}, Base.ReinterpretArray{T,1,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,1,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,1,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where T) where #s664, adjQ::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:LinearAlgebra.AbstractQ where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/qr.jl:744
# [75] *(u::LinearAlgebra.Adjoint{T,#s664} where #s664<:(AbstractArray{T,1} where T) where T, A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractQ where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/qr.jl:732
# [76] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.LQPackedQ where #s664, adjB::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(Union{DenseArray{T,1}, DenseArray{T,2}, Base.ReinterpretArray{T,1,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,1,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,1,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where T) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/lq.jl:219
# [77] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{DenseArray{T,2}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where T) where #s664, adjQ::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:LinearAlgebra.LQPackedQ where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/lq.jl:256
# [78] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s664, adjB::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:599
# [79] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s664, adjB::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:601
# [80] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s664, adjB::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:603
# [81] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s664, adjB::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:600
# [82] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}, LinearAlgebra.Symmetric{Complex{T},S}} where S where T<:Real) where #s664, adjB::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:602
# [83] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s664, adjB::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}, LinearAlgebra.Symmetric{Complex{T},S}} where S where T<:Real) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:604
# [84] *(adjD::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.Diagonal where #s664, adjA::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/diagonal.jl:373
# [85] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(AbstractArray{T,1} where T) where #s664, B::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:1026
# [86] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s664, adjD::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:LinearAlgebra.Diagonal where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/diagonal.jl:372
# [87] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s664, B::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(AbstractArray{T,1} where T) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:1035
# [88] *(D::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.Diagonal where #s664, B::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:LinearAlgebra.Diagonal where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/diagonal.jl:259
# [89] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:SparseArrays.AbstractSparseMatrixCSC where #s664, B::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:SparseArrays.AbstractSparseMatrixCSC where #s662) in SparseArrays at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SparseArrays/src/linalg.jl:168
# [90] *(u::LinearAlgebra.Adjoint{T,#s664} where #s664<:(AbstractArray{T,1} where T) where T, v::LinearAlgebra.Adjoint{T,#s664} where #s664<:(AbstractArray{T,1} where T) where T) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/adjtrans.jl:256
# [91] *(u::LinearAlgebra.Adjoint{T,#s664} where #s664<:(AbstractArray{T,1} where T) where T, v::LinearAlgebra.Transpose{#s664,#s663} where #s663<:(LinearAlgebra.Adjoint{T,#s664} where #s664<:(AbstractArray{T,1} where T) where T) where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/adjtrans.jl:267
# [92] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:Union{DenseArray{T,2}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where #s664, x::Union{DenseArray{S,1}, Base.ReinterpretArray{S,1,S1,A} where S1 where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{S,1,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{S,1,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}}) where {T<:Union{Complex{Float32}, Complex{Float64}, Float32, Float64}, S} in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/matmul.jl:106
# [93] *(xformA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.UpperTriangular where #s664, B::LinearAlgebra.LowerTriangular) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:1813
# [94] *(xformA::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:LinearAlgebra.UnitUpperTriangular where #s662, B::LinearAlgebra.LowerTriangular) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:1822
# [95] *(xformA::LinearAlgebra.Adjoint{#s660,#s659} where #s659<:LinearAlgebra.LowerTriangular where #s660, B::LinearAlgebra.UpperTriangular) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:1831
# [96] *(xformA::LinearAlgebra.Adjoint{#s658,#s657} where #s657<:LinearAlgebra.UnitLowerTriangular where #s658, B::LinearAlgebra.UpperTriangular) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:1840
# [97] *(adjA::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664, B::LinearAlgebra.AbstractTriangular) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:1931
# [98] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664, B::LinearAlgebra.Adjoint{#s662,#s661} where #s661<:(AbstractArray{T,2} where T) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:2134
# [99] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664, B::LinearAlgebra.Transpose{#s662,#s661} where #s661<:LinearAlgebra.AbstractTriangular where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:2639
# [100] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664, B::LinearAlgebra.Transpose{#s662,#s661} where #s661<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}, LinearAlgebra.Symmetric{Complex{T},S}} where S where T<:Real) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:1046
# [101] *(X::Union{DenseArray{T,2}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, LinearAlgebra.Adjoint{#s664,#s663} where #s663<:Union{DenseArray{T,2}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, LinearAlgebra.LowerTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgebra.UnitLowerTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgebra.UnitUpperTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgebra.UpperTriangular{T,S} where S<:AbstractArray{T,2}} where #s664, LinearAlgebra.LowerTriangular{T,S} where S<:AbstractArray{T,2}, LinearAlgebra.Transpose{#s662,#s661} where #s661<:Union{DenseArray{T,2}, Base.ReinterpretArray{T,2,S,A} where S wh ...
# [102] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664, B::LinearAlgebra.Transpose{#s662,#s661} where #s661<:(AbstractArray{T,2} where T) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:2643
# [103] *(A::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664, B::LinearAlgebra.Transpose{#s662,#s661} where #s661<:(AbstractArray{T,1} where T) where #s662) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:2644
# ...
# [305] *(A::SuiteSparse.CHOLMOD.Sparse, B::SuiteSparse.CHOLMOD.Sparse) in SuiteSparse.CHOLMOD at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SuiteSparse/src/cholmod.jl:1233
# [306] *(A::SuiteSparse.CHOLMOD.Sparse, B::SuiteSparse.CHOLMOD.Dense) in SuiteSparse.CHOLMOD at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SuiteSparse/src/cholmod.jl:1234
# [307] *(A::SuiteSparse.CHOLMOD.Sparse, B::Union{Array{T,1}, Array{T,2}} where T) in SuiteSparse.CHOLMOD at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SuiteSparse/src/cholmod.jl:1235
# [308] *(A::SuiteSparse.CHOLMOD.Sparse{Tv}, adjB::LinearAlgebra.Adjoint{Tv,SuiteSparse.CHOLMOD.Sparse{Tv}}) where Tv<:Float64 in SuiteSparse.CHOLMOD at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SuiteSparse/src/cholmod.jl:1238
# [309] *(A::LinearAlgebra.Symmetric{Float64,SparseArrays.SparseMatrixCSC{Float64,Ti}}, B::Union{SparseArrays.SparseMatrixCSC{Float64,Ti}, SparseArrays.SparseVector{Float64,Ti}}) where Ti in SuiteSparse.CHOLMOD at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SuiteSparse/src/cholmod.jl:1858
# [310] *(A::LinearAlgebra.Hermitian{Complex{Float64},SparseArrays.SparseMatrixCSC{Complex{Float64},Ti}}, B::Union{SparseArrays.SparseMatrixCSC{Complex{Float64},Ti}, SparseArrays.SparseVector{Complex{Float64},Ti}}) where Ti in SuiteSparse.CHOLMOD at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SuiteSparse/src/cholmod.jl:1860
# [311] *(A::LinearAlgebra.Hermitian{Float64,SparseArrays.SparseMatrixCSC{Float64,Ti}}, B::Union{SparseArrays.SparseMatrixCSC{Float64,Ti}, SparseArrays.SparseVector{Float64,Ti}}) where Ti in SuiteSparse.CHOLMOD at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SuiteSparse/src/cholmod.jl:1862
# [312] *(A::Union{SparseArrays.SparseMatrixCSC{Float64,Ti}, SparseArrays.SparseVector{Float64,Ti}}, B::LinearAlgebra.Symmetric{Float64,SparseArrays.SparseMatrixCSC{Float64,Ti}}) where Ti in SuiteSparse.CHOLMOD at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SuiteSparse/src/cholmod.jl:1865
# [313] *(A::Union{SparseArrays.SparseMatrixCSC{Complex{Float64},Ti}, SparseArrays.SparseVector{Complex{Float64},Ti}}, B::LinearAlgebra.Hermitian{Complex{Float64},SparseArrays.SparseMatrixCSC{Complex{Float64},Ti}}) where Ti in SuiteSparse.CHOLMOD at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SuiteSparse/src/cholmod.jl:1867
# [314] *(A::Union{SparseArrays.SparseMatrixCSC{Float64,Ti}, SparseArrays.SparseVector{Float64,Ti}}, B::LinearAlgebra.Hermitian{Float64,SparseArrays.SparseMatrixCSC{Float64,Ti}}) where Ti in SuiteSparse.CHOLMOD at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SuiteSparse/src/cholmod.jl:1869
# [315] *(x::AbstractArray{#s69,2} where #s69<:Number) in Base at abstractarraymath.jl:98
# [316] *(B::Number, A::LinearAlgebra.SymTridiagonal) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/tridiag.jl:161
# [317] *(B::Number, A::LinearAlgebra.Tridiagonal) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/tridiag.jl:660
# [318] *(x::Number, A::LinearAlgebra.UpperTriangular) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:847
# [319] *(x::Number, A::LinearAlgebra.UnitUpperTriangular) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:850
# [320] *(x::Number, A::LinearAlgebra.LowerTriangular) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:847
# [321] *(x::Number, A::LinearAlgebra.UnitLowerTriangular) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:850
# [322] *(x::Number, A::LinearAlgebra.Symmetric) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:614
# [323] *(x::Number, D::LinearAlgebra.Diagonal) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/diagonal.jl:159
# [324] *(B::Number, A::LinearAlgebra.Bidiagonal) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/bidiag.jl:328
# [325] *(a::Number, x::Union{SubArray{T,1,#s664,Tuple{Base.Slice{Base.OneTo{Int64}},Int64},false} where #s664<:SparseArrays.AbstractSparseMatrixCSC, SparseArrays.SparseVector{T,Ti} where Ti<:Integer} where T) in SparseArrays at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/SparseArrays/src/sparsevector.jl:1407
# [326] *(A::Number, B::AbstractArray) in Base at arraymath.jl:52
# [327] *(A::AbstractArray, B::Number) in Base at arraymath.jl:55
# [328] *(s1::Union{AbstractChar, AbstractString}, ss::Union{AbstractChar, AbstractString}...) in Base at strings/basic.jl:231
# [329] *(r1::Union{Regex, AbstractChar, AbstractString}, rs::Union{Regex, AbstractChar, AbstractString}...) in Base at regex.jl:640
# [330] *(index::CartesianIndex, a::Integer) in Base.IteratorsMD at multidimensional.jl:121
# [331] *(::Number, ::Missing) in Base at missing.jl:116
# [332] *(d::AbstractString, x::Missing) in Base at missing.jl:175
# [333] *(x::P, y::Real) where P<:Dates.Period in Dates at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/Dates/src/periods.jl:90
# [334] *(u::AbstractArray{T,1} where T, v::Union{LinearAlgebra.Adjoint{T,#s664}, LinearAlgebra.Transpose{T,#s664}} where #s664<:(AbstractArray{T,1} where T) where T) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/adjtrans.jl:253
# [335] *(A::AbstractArray{T,2} where T, B::LinearAlgebra.AbstractTriangular) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:2095
# [336] *(A::AbstractArray{T,2} where T, adjB::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:2102
# [337] *(A::AbstractArray{T,2} where T, transB::LinearAlgebra.Transpose{#s664,#s663} where #s663<:LinearAlgebra.AbstractTriangular where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/triangular.jl:2110
# [338] *(A::AbstractArray{T,2} where T, transB::LinearAlgebra.Transpose{#s664,#s663} where #s663<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}, LinearAlgebra.Symmetric{Complex{T},S}} where S where T<:Real) where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:586
# [339] *(A::AbstractArray{T,2} where T, adjB::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/symmetric.jl:590
# [340] *(A::AbstractArray{T,2} where T, D::LinearAlgebra.Diagonal) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/diagonal.jl:170
# [341] *(A::AbstractArray{T,2} where T, adjR::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractRotation where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/givens.jl:14
# [342] *(A::AbstractArray{T,2}, x::AbstractArray{S,1}) where {T, S} in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/matmul.jl:50
# [343] *(a::AbstractArray{T,1} where T, transB::LinearAlgebra.Transpose{#s664,#s663} where #s663<:(AbstractArray{T,2} where T) where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/matmul.jl:56
# [344] *(a::AbstractArray{T,1} where T, adjB::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:(AbstractArray{T,2} where T) where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/matmul.jl:60
# [345] *(A::AbstractArray{T,1} where T, adjR::LinearAlgebra.Adjoint{#s664,#s663} where #s663<:LinearAlgebra.AbstractRotation where #s664) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/givens.jl:13
# [346] *(a::AbstractArray{T,1} where T, B::AbstractArray{T,2} where T) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/matmul.jl:63
# [347] *(A::AbstractArray{T,2} where T, B::AbstractArray{T,2} where T) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/matmul.jl:152
# [348] *(A::LinearAlgebra.LQ{TA,S} where S<:AbstractArray{TA,2}, B::Union{DenseArray{TB,1}, DenseArray{TB,2}, Base.ReinterpretArray{TB,1,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReinterpretArray{TB,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{TB,1,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{TB,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{TB,1,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, SubArray{TB,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}}) where {TA, TB} in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/lq.jl:180
# [349] *(J1::LinearAlgebra.UniformScaling, J2::LinearAlgebra.UniformScaling) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/uniformscaling.jl:194
# [350] *(J::LinearAlgebra.UniformScaling, B::BitArray{2}) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/uniformscaling.jl:196
# [351] *(A::AbstractArray{T,2} where T, J::LinearAlgebra.UniformScaling) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/uniformscaling.jl:197
# [352] *(J::LinearAlgebra.UniformScaling, A::Union{AbstractArray{T,1}, AbstractArray{T,2}} where T) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/uniformscaling.jl:198
# [353] *(x::Number, J::LinearAlgebra.UniformScaling) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/uniformscaling.jl:199
# [354] *(J::LinearAlgebra.UniformScaling, x::Number) in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/uniformscaling.jl:200
# [355] *(F::LinearAlgebra.Hessenberg{#s664,#s663,S,W,V} where V<:Number where W<:(AbstractArray{T,1} where T) where S<:(AbstractArray{T,2} where T) where #s663<:AbstractArray{T,2} where #s664, x::S) where {T, S<:Number} in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/hessenberg.jl:541
# [356] *(x::S, F::LinearAlgebra.Hessenberg{#s664,#s663,S,W,V} where V<:Number where W<:(AbstractArray{T,1} where T) where S<:(AbstractArray{T,2} where T) where #s663<:AbstractArray{T,2} where #s664) where {T, S<:Number} in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/hessenberg.jl:549
# [357] *(R::LinearAlgebra.AbstractRotation{T}, A::Union{AbstractArray{S,1}, AbstractArray{S,2}}) where {T, S} in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/givens.jl:10
# [358] *(A::AbstractArray{T,2}, R::LinearAlgebra.AbstractRotation{S}) where {T, S} in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/givens.jl:21
# [359] *(G1::LinearAlgebra.Givens{T}, G2::LinearAlgebra.Givens{T}) where T in LinearAlgebra at /home/elbeltagy/temp/juliaExpr/julia1.4.1/julia-1.4.1/share/julia/stdlib/v1.4/LinearAlgebra/src/givens.jl:383
# [360] *(a, b, c, xs...) in Base at operators.jl:529

# %% [markdown]
# ## Traits

# %% [markdown]
# Please more on traits in these excellent blog [here](https://white.ucc.asn.au/2018/10/03/Dispatch,-Traits-and-Metaprogramming-Over-Reflection.html) and [here]()

# %% [markdown]
# # Must watch video

# %% [markdown]
# https://www.youtube.com/watch?v=kc9HwsxE1OY
